# %% [markdown]
# <a href="https://colab.research.google.com/github/subarnab219/Binary-prediction-using-Catboost/blob/master/Introduction_to_TensorFlow_for_Artificial_Intelligence%2C_Machine_Learning%2C_and_Deep_Learning_Week1_The_%E2%80%98Hello_World%E2%80%99_of_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import TensorFlow 2.0 Library**

# %%
# !pip install -q tensorflow==2.0.0-beta1

import tensorflow as tf
# Out:
#      |████████████████████████████████| 87.9MB 62.5MB/s
#      |████████████████████████████████| 3.1MB 35.7MB/s
#      |████████████████████████████████| 501kB 43.7MB/s

# %% [markdown]
# **Import Other Libraries**

# %%
import numpy as np

# %% [markdown]
# **Define a neural network with 1 neuron and input data**

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(units=1, input_shape=[1])
])

# %% [markdown]
# **Define a loss function and an optimizer**

# %%
model.compile(optimizer='adam',
              loss='mean_squared_error', metrics=['accuracy'])

# %% [markdown]
# **Input Data**

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0])
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0])

# %% [markdown]
# **Fit Model**

# %%
model.fit(xs, ys, epochs = 500)
# Out:
# Train on 6 samples
# Epoch 1/500
# 6/6 [==============================] - 0s 6ms/sample - loss: 0.1684 - accuracy: 0.1667
# Epoch 2/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.1671 - accuracy: 0.1667
# Epoch 3/500
# 6/6 [==============================] - 0s 312us/sample - loss: 0.1659 - accuracy: 0.1667
# Epoch 4/500
# 6/6 [==============================] - 0s 272us/sample - loss: 0.1647 - accuracy: 0.1667
# Epoch 5/500
# 6/6 [==============================] - 0s 334us/sample - loss: 0.1635 - accuracy: 0.1667
# Epoch 6/500
# 6/6 [==============================] - 0s 310us/sample - loss: 0.1623 - accuracy: 0.1667
# Epoch 7/500
# 6/6 [==============================] - 0s 385us/sample - loss: 0.1612 - accuracy: 0.1667
# Epoch 8/500
# 6/6 [==============================] - 0s 459us/sample - loss: 0.1600 - accuracy: 0.1667
# Epoch 9/500
# 6/6 [==============================] - 0s 399us/sample - loss: 0.1588 - accuracy: 0.1667
# Epoch 10/500
# ...

# %% [markdown]
# **Predict Outcome**

# %%
print(model.predict([10.0]))
# Out:
# [[17.170942]]
